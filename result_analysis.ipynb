# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os
import pickle

import scipy as sci
import cvxpy as cp
from cvxopt import matrix, solvers
import sklearn.covariance as sk_cov
from pdb import set_trace as bp

# %%
from BackTestingSystem import bt
import StrategyResources as strat_res
import pyRMT.pyRMT as rmt
# Out:
# /home/l7/dev/repos/classes/portfolio_research_project/BackTestingSystem

# %%
# %ls data/
# Out:
# mean_optima_df_2019-10-14-13-17-32.pckl  result_2019-10-14-13-06-12.pckl
# mean_optima_df_2019-10-14-13-17-51.pckl  result_2019-10-14-13-06-22.pckl
# result_2019-10-14-13-04-37.pckl

# %%
data1 = pd.read_pickle('data/mean_optima_df_2019-10-14-13-17-51.pckl')
# data = pickle.load('data/mean_optima_df_2019-10-14-13-17-51.pckl')
data
# Out:
#                                test_name    values
# 0    ledoit-wolf_mdp_original_days=1_150  7.325902
# 1   ledoit-wolf_mdp_original_days=10_150  7.559895
# 2   ledoit-wolf_mdp_original_days=20_150  7.190408
# 3   ledoit-wolf_mdp_original_days=30_150  7.417773
# 4   ledoit-wolf_mdp_original_days=60_150  7.649848
# 5  ledoit-wolf_mdp_original_days=100_150  7.603808
# 6  ledoit-wolf_mdp_original_days=180_150  7.554801
# 7  ledoit-wolf_mdp_original_days=200_150  7.371068

# %%
gmvp_results = pd.read_pickle('data/result_2019-10-14-13-04-37.pckl')
# data = pickle.load('data/mean_optima_df_2019-10-14-13-17-51.pckl')
gmvp_results
# Out:
# {'ledoit-wolf_gmvp_days=1_150': <ffn.core.PerformanceStats at 0x7f478032f090>,
#  'ledoit-wolf_gmvp_days=10_150': <ffn.core.PerformanceStats at 0x7f478077f210>,
#  'ledoit-wolf_gmvp_days=20_150': <ffn.core.PerformanceStats at 0x7f477fbe3050>,
#  'ledoit-wolf_gmvp_days=30_150': <ffn.core.PerformanceStats at 0x7f477fa10290>,
#  'ledoit-wolf_gmvp_days=60_150': <ffn.core.PerformanceStats at 0x7f477fa168d0>,
#  'ledoit-wolf_gmvp_days=100_150': <ffn.core.PerformanceStats at 0x7f477fdb7c10>,
#  'ledoit-wolf_gmvp_days=180_150': <ffn.core.PerformanceStats at 0x7f477fc151d0>,
#  'ledoit-wolf_gmvp_days=200_150': <ffn.core.PerformanceStats at 0x7f477fcb6ad0>}

# %%
gmvp_results.plot()

# %%
data_results = pd.read_pickle('data/result_2019-10-14-13-06-12.pckl')
# data = pickle.load('data/mean_optima_df_2019-10-14-13-17-51.pckl')
data_results
# Out:
# {'ledoit-wolf_mdp_D_days=1_150': <ffn.core.PerformanceStats at 0x7f47801ae610>,
#  'ledoit-wolf_mdp_D_days=10_150': <ffn.core.PerformanceStats at 0x7f47800f9110>,
#  'ledoit-wolf_mdp_D_days=20_150': <ffn.core.PerformanceStats at 0x7f4780062410>,
#  'ledoit-wolf_mdp_D_days=30_150': <ffn.core.PerformanceStats at 0x7f478022efd0>,
#  'ledoit-wolf_mdp_D_days=60_150': <ffn.core.PerformanceStats at 0x7f477f9362d0>,
#  'ledoit-wolf_mdp_D_days=100_150': <ffn.core.PerformanceStats at 0x7f477f92db90>,
#  'ledoit-wolf_mdp_D_days=180_150': <ffn.core.PerformanceStats at 0x7f477f8ae1d0>,
#  'ledoit-wolf_mdp_D_days=200_150': <ffn.core.PerformanceStats at 0x7f477f80a610>}
